# %%
import pandas as pd
import folium
import os
import random
from PIL import Image
from sklearn.utils import shuffle

# %%
gbif: pd.DataFrame = pd.read_csv("./data/cleaned/gbif.csv")

# %%
def get_image(genus: str) -> Image:
    directory_path: str = f"./data/Mushrooms/{genus}/"
    directory: list = os.listdir(directory_path)
    filepath: str = random.choice(directory)
    image: Image = Image.open(f"{directory_path}{filepath}")
    return image

# %%
def create_map(genus: str) -> folium.Map:
    location = gbif[['decimalLatitude', 'decimalLongitude']]
    locs = location[gbif.genus == genus]
    # locs = locs.sample(frac = 1)
    locs = shuffle(locs, random_state = 101)
    loc_list = locs.values.tolist()
    x, y = loc_list[0]
    map_ = folium.Map(location = [x, y], zoom_start = 10)

    for point in range(0, min(len(loc_list), 500)):
        folium.Marker(loc_list[point]).add_to(map_)
    
    return map_

# %%
create_map('Hygrocybe')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
